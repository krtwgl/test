# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ## Cookiecutter

# %% [markdown]
# Cookiecutter is a command-line utility that creates projects from cookiecutter templates. In the context of data science, using cookiecutter templates can significantly streamline the project setup process, enhance reproducibility, and encourage best practices. In this tutorial, we'll guide you through the process of cloning a data science cookiecutter template from GitHub, exploring its structure, and highlighting the benefits it offers.

# %% [markdown]
# #### Step 1: Install the Cookiecutter Library and start a project

# %%
# !pip install cookiecutter
# Out:
# Requirement already satisfied: cookiecutter in c:\users\asus4\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: binaryornot>=0.4.4 in c:\users\asus4\anaconda3\lib\site-packages (from cookiecutter) (0.4.4)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in c:\users\asus4\anaconda3\lib\site-packages (from cookiecutter) (3.1.6)
# Requirement already satisfied: click<9.0.0,>=7.0 in c:\users\asus4\anaconda3\lib\site-packages (from cookiecutter) (8.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\asus4\anaconda3\lib\site-packages (from cookiecutter) (6.0.3)
# Requirement already satisfied: python-slugify>=4.0.0 in c:\users\asus4\anaconda3\lib\site-packages (from cookiecutter) (8.0.4)
# Requirement already satisfied: requests>=2.23.0 in c:\users\asus4\anaconda3\lib\site-packages (from cookiecutter) (2.32.5)
# Requirement already satisfied: arrow in c:\users\asus4\anaconda3\lib\site-packages (from cookiecutter) (1.4.0)
# Requirement already satisfied: rich in c:\users\asus4\anaconda3\lib\site-packages (from cookiecutter) (14.2.0)
# Requirement already satisfied: colorama in c:\users\asus4\anaconda3\lib\site-packages (from click<9.0.0,>=7.0->cookiecutter) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus4\anaconda3\lib\site-packages (from Jinja2<4.0.0,>=2.7->cookiecutter) (3.0.2)
# Requirement already satisfied: chardet>=3.0.2 in c:\users\asus4\anaconda3\lib\site-packages (from binaryornot>=0.4.4->cookiecutter) (5.2.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\asus4\anaconda3\lib\site-packages (from python-slugify>=4.0.0->cookiecutter) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus4\anaconda3\lib\site-packages (from requests>=2.23.0->cookiecutter) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus4\anaconda3\lib\site-packages (from requests>=2.23.0->cookiecutter) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus4\anaconda3\lib\site-packages (from requests>=2.23.0->cookiecutter) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus4\anaconda3\lib\site-packages (from requests>=2.23.0->cookiecutter) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\asus4\anaconda3\lib\site-packages (from arrow->cookiecutter) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\asus4\anaconda3\lib\site-packages (from arrow->cookiecutter) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus4\anaconda3\lib\site-packages (from python-dateutil>=2.7.0->arrow->cookiecutter) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\asus4\anaconda3\lib\site-packages (from rich->cookiecutter) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asus4\anaconda3\lib\site-packages (from rich->cookiecutter) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asus4\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->cookiecutter) (0.1.2)
